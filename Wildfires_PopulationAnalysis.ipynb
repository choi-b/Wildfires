# %%
## Import Libraries ##
import sqlite3
from sqlite3 import Error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame
from sqlalchemy import create_engine, MetaData, Table, select, func, desc

# %% [markdown]
# ## Connect to Database

# %%
engine = create_engine('sqlite:///C:/Users/604906/Desktop/BAH/Data Science/WiDS/Wildfires/188-million-us-wildfires/FPA_FOD_20170508.sqlite')

# %%
connection = engine.connect()

# %%
# Print tables names of database to make sure connection worked
print(engine.table_names())
# Out:
# ['ElementaryGeometries', 'Fires', 'KNN', 'NWCG_UnitIDActive_20170109', 'SpatialIndex', 'geometry_columns', 'geometry_columns_auth', 'geometry_columns_field_infos', 'geometry_columns_statistics', 'geometry_columns_time', 'idx_Fires_Shape', 'idx_Fires_Shape_node', 'idx_Fires_Shape_parent', 'idx_Fires_Shape_rowid', 'spatial_ref_sys', 'spatial_ref_sys_aux', 'spatialite_history', 'sql_statements_log', 'sqlite_sequence', 'views_geometry_columns', 'views_geometry_columns_auth', 'views_geometry_columns_field_infos', 'views_geometry_columns_statistics', 'virts_geometry_columns', 'virts_geometry_columns_auth', 'virts_geometry_columns_field_infos', 'virts_geometry_columns_statistics']

# %% [markdown]
# ## Connect to Fires Table

# %%
# Function in SqlAlchemy Library that reflects the table information (such as datatypes, primary keys, etc.)
metadata = MetaData()

# %%
# Create a Table object that can be used to query the data
Fires = Table('Fires', metadata, autoload = True, autoload_with=engine)

# %%
try:
    stmt = 'SELECT * FROM Fires'
    
    # Execute the statement and store all the records: results
    results = connection.execute(stmt).fetchall()

    # Create a DataFrame from the results: df
    fires = pd.DataFrame(results)

    # Set column names
    fires.columns = results[0].keys()

except Exception as err:
    print(err)

# %%
#Look at columns in Fires
#fires.info()

# %% [markdown]
# ## Pull in Climate Data ##

# %%
climate_df = pd.read_csv('climate_df.csv')

# %%
climate_df.head(5) #view some data
# Out:
#   state   county      climate  climate_zone moisture
# 0    AL  Autauga    Hot-Humid             3        A
# 1    AL  Baldwin    Hot-Humid             2        A
# 2    AL  Barbour    Hot-Humid             3        A
# 3    AL     Bibb  Mixed-Humid             3        A
# 4    AL   Blount  Mixed-Humid             3        A

# %%
#Fix Alaska county names that don't match / Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('Prince of Wales- Outer Ketchikan', 'Prince of Wales-Outer Ketchikan')
climate_df['county'] = climate_df['county'].replace('Skagway-Hoonah- Angoon', 'Skagway-Hoonah-Angoon')
# Correct county name in fires DF since it isn't accurate
fires['FIPS_NAME'] = fires['FIPS_NAME'].replace('Skagway-Yakutat-Angoon', 'Skagway-Hoonah-Angoon')

# %%
#Fix Georgie counties
# Multiple states with same county name
climate_df[climate_df['county'] == 'Bryan']['state'].value_counts()
climate_df[(climate_df['state'] == 'GA') & (climate_df['county'] == 'Bryan')]
# Add row to climate_df to match with Bryan South (GA)
climate_df = climate_df.append({'state':'GA', 'county':'Bryan South', 'climate':'Hot-Humid', 'climate_zone':'2', \
                                'moisture':'A'}, ignore_index=True)

# %%
# Multiple states with same county name
climate_df[climate_df['county'] == 'DeKalb']['state'].value_counts()
climate_df[(climate_df['state'] == 'GA') & (climate_df['county'] == 'DeKalb')]
climate_df[(climate_df['state'] == 'TN') & (climate_df['county'] == 'DeKalb')]
# Correct Georgia and Tennessee county names in climate DF
climate_df.loc[428]['county'] = 'Dekalb'
climate_df.loc[2446]['county'] = 'Dekalb'

# %%
#Fix Illinois county names
# Correct county name in fires DF since county name isn't correct (for both Illinois and Texas)
fires['FIPS_NAME'] = fires['FIPS_NAME'].replace('De Witt', 'DeWitt')
# Correct county name in fires DF since county name isn't correct
fires['FIPS_NAME'] = fires['FIPS_NAME'].replace('Cumberlin', 'Cumberland')

# %%
#Fix Louisiana Counties
# Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('East Carroll', 'E. Carroll')
# Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('St. LanB', 'St. Landry')

# %%
#Fix Montana and New Mexico Counties
# Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('Glacier', 'Glacier County')
# Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('Doña Ana', 'Dona Ana')

# %%
#Fix Virginia Counties
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Buena Vista')]
# Correct county name in climate DF
climate_df.loc[2836]['county'] = 'Buena Vista City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Chesapeake')]
# Correct county name in climate DF
climate_df.loc[2843]['county'] = 'Chesapeake City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Colonial Heights')]
# Correct county name in climate DF
climate_df.loc[2847]['county'] = 'Colonial Heights City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Hampton')]
# Correct county name in climate DF
climate_df.loc[2875]['county'] = 'Hampton City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Newport News')]
# Correct county name in climate DF
climate_df.loc[2904]['county'] = 'Newport News City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Petersburg')]
# Correct county name in climate DF
climate_df.loc[2913]['county'] = 'Petersburg City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Richmond City')]
# Correct county name in climate DF
climate_df['county'] = climate_df['county'].replace('Richmond City', 'Richmond (city)')
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Suffolk')]
# Correct county name in climate DF
climate_df.loc[2939]['county'] = 'Suffolk City'
climate_df[(climate_df['state'] == 'VA') & (climate_df['county'] == 'Virginia Beach')]
# Correct county name in climate DF
climate_df.loc[2943]['county'] = 'Virginia Beach City'
# Correct typo in fires DF
fires['FIPS_NAME'] = fires['FIPS_NAME'].replace('Virginia Beach city', 'Virginia Beach City')

# %% [markdown]
# ## Check if all counties are aligned ##

# %%
#Checked by Tim Balton
# All non-matching counties -- all in Puerto Rico
fires[~fires['FIPS_NAME'].isin(climate_df['county'])].groupby('STATE')['FIPS_NAME'].value_counts().sort_index()
# Out:
# STATE  FIPS_NAME
# PR     Cabo Rojo           46
#        Gurabo Municipio     1
#        Lajas                8
#        Vieques             21
# Name: FIPS_NAME, dtype: int64

# %% [markdown]
# ## Merge Fires and Climate DFs ##

# %%
# Merge on state and county
fires = \
fires.merge(climate_df, left_on=['STATE', 'FIPS_NAME'], right_on=['state', 'county'], how='left')

# %%
# Drop redundant columns
fires.drop(['state', 'county'], axis=1, inplace=True)
# Make all column names uppercase for consistency
fires = fires.rename(columns={'climate':'CLIMATE', 'climate_zone':'CLIMATE_ZONE', 'moisture':'MOISTURE'})

# %%
#Check null data
#fires.isnull().sum()

# %% [markdown]
# ## United States Population Data

# %%
population_df = pd.read_csv('county_population.csv', encoding = "ISO-8859-1")
#reference: https://stackoverflow.com/questions/18171739/unicodedecodeerror-when-reading-csv-file-in-pandas-with-python

# %%
#View first five rows
population_df.head(5)
# Out:
#    fips  state_fips  county_fips                 areaname     state_name  \
# 0     0           0            0            United States  United States
# 1  1000           1            0                  Alabama        Alabama
# 2  1001           1            1           Autauga County        Alabama
# 3  1001           1         1001  Autauga County, Alabama        Alabama
# 4  1003           1            3           Baldwin County        Alabama
#
#       county_name  fipsst  fipsco  region  division  ...    pop2008  \
# 0   United States       0       0     NaN       NaN  ...        NaN
# 1         Alabama       1       0     3.0       6.0  ...  4677464.0
# 2  Autauga County       1       1     3.0       6.0  ...    50354.0
# 3  Autauga County       1    1001     NaN       NaN  ...        NaN
# 4  Baldwin County       1       3     3.0       6.0  ...   176212.0
#
#      pop2009     pop19904  pop20104  base20104  pop2010  pop2011  pop2012  \
# 0        NaN  248790925.0       NaN        NaN      NaN      NaN      NaN
# 1  4708708.0    4040389.0       NaN        NaN      NaN      NaN      NaN
# 2    50756.0      34222.0       NaN        NaN      NaN      NaN      NaN
# 3        NaN          NaN   54571.0    54571.0  54684.0  55275.0  55192.0
# 4   179878.0      98280.0       NaN        NaN      NaN      NaN      NaN
#
#    pop2013  pop2014
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3  55136.0  55395.0
# 4      NaN      NaN
#
# [5 rows x 58 columns]

# %%
#Find unique count of counties in the U.S.
population_df.fips.nunique()
#population_df.state_name.nunique()
# Out:
# 3204

# %%
population_df.describe()
# Out:
#                fips   state_fips   county_fips       fipsst        fipsco  \
# count   6346.000000  6346.000000   6346.000000  6346.000000   6346.000000
# mean   30352.355027    30.249291  15095.185156    30.249291  15095.185156
# std    15187.032244    15.168804  18522.039427    15.168804  18522.039427
# min        0.000000     0.000000      0.000000     0.000000      0.000000
# 25%    18171.000000    18.000000     77.000000    18.000000     77.000000
# 50%    29174.000000    29.000000    592.500000    29.000000    592.500000
# 75%    45078.500000    45.000000  29144.500000    45.000000  29144.500000
# max    56045.000000    56.000000  56045.000000    56.000000  56045.000000
#
#             region     division       pop1970       pop1971       pop1972  \
# count  3194.000000  3194.000000  3.190000e+03  3.190000e+03  3.190000e+03
# mean      2.668754     5.191296  1.911931e+05  1.945065e+05  1.968177e+05
# std       0.807408     1.973685  3.677747e+06  3.741025e+06  3.784870e+06
# min       1.000000     1.000000  6.400000e+01  1.000000e+02  1.000000e+02
# 25%       2.000000     4.000000  9.281250e+03  9.400000e+03  9.525000e+03
# 50%       3.000000     5.000000  1.895900e+04  1.920000e+04  1.970000e+04
# 75%       3.000000     7.000000  4.536250e+04  4.627500e+04  4.705000e+04
# max       4.000000     9.000000  2.033020e+08  2.068260e+08  2.092830e+08
#
#        ...       pop2008       pop2009      pop19904      pop20104  \
# count  ...  3.194000e+03  3.194000e+03  3.193000e+03  3.142000e+03
# mean   ...  1.905916e+05  1.922395e+05  2.337528e+05  9.826204e+04
# std    ...  1.158680e+06  1.169814e+06  4.500641e+06  3.129467e+05
# min    ...  4.000000e+01  4.500000e+01  1.070000e+02  8.200000e+01
# 25%    ...  1.116925e+04  1.110100e+04  1.044600e+04  1.111450e+04
# 50%    ...  2.612800e+04  2.608900e+04  2.275300e+04  2.587200e+04
# 75%    ...  7.038100e+04  7.058725e+04  5.808600e+04  6.678000e+04
# max    ...  3.658037e+07  3.696166e+07  2.487909e+08  9.818605e+06
#
#           base20104       pop2010       pop2011       pop2012       pop2013  \
# count  3.142000e+03  3.142000e+03  3.142000e+03  3.142000e+03  3.142000e+03
# mean   9.826802e+04  9.845546e+04  9.921121e+04  9.997202e+04  1.007312e+05
# std    3.129579e+05  3.135523e+05  3.167124e+05  3.200056e+05  3.232352e+05
# min    8.200000e+01  8.300000e+01  9.000000e+01  8.300000e+01  8.900000e+01
# 25%    1.111450e+04  1.109125e+04  1.108975e+04  1.101300e+04  1.103575e+04
# 50%    2.587200e+04  2.583550e+04  2.579750e+04  2.582650e+04  2.576350e+04
# 75%    6.678050e+04  6.689450e+04  6.711150e+04  6.723200e+04  6.749425e+04
# max    9.818664e+06  9.827231e+06  9.898214e+06  9.974868e+06  1.005400e+07
#
#             pop2014
# count  3.142000e+03
# mean   1.014822e+05
# std    3.261742e+05
# min    8.600000e+01
# 25%    1.102825e+04
# 50%    2.571450e+04
# 75%    6.776225e+04
# max    1.011670e+07
#
# [8 rows x 55 columns]

# %%
population_df2 = pd.read_csv('PopulationEstimates.csv', skiprows=2)
#https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/
#population estimates from 2010-2018

# %%
population_df2
# Out:
#          FIPS State                        Area_Name  \
# 0         0.0    US                    United States
# 1      1000.0    AL                          Alabama
# 2      1001.0    AL                   Autauga County
# 3      1003.0    AL                   Baldwin County
# 4      1005.0    AL                   Barbour County
# ...       ...   ...                              ...
# 3269  72147.0    PR   Vieques Municipio, Puerto Rico
# 3270  72149.0    PR  Villalba Municipio, Puerto Rico
# 3271  72151.0    PR   Yabucoa Municipio, Puerto Rico
# 3272  72153.0    PR     Yauco Municipio, Puerto Rico
# 3273      NaN   NaN                              NaN
#
#       Rural-urban_Continuum Code_2003  Rural-urban_Continuum Code_2013  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 2.0                              2.0
# 3                                 4.0                              3.0
# 4                                 6.0                              6.0
# ...                               ...                              ...
# 3269                              7.0                              7.0
# 3270                              2.0                              2.0
# 3271                              1.0                              1.0
# 3272                              3.0                              2.0
# 3273                              NaN                              NaN
#
#       Urban_Influence_Code_2003  Urban_Influence_Code_2013  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           2.0                        2.0
# 3                           5.0                        2.0
# 4                           6.0                        6.0
# ...                         ...                        ...
# 3269                       12.0                       12.0
# 3270                        2.0                        2.0
# 3271                        1.0                        1.0
# 3272                        2.0                        2.0
# 3273                        NaN                        NaN
#
#       Economic_typology_2015 CENSUS_2010_POP ESTIMATES_BASE_2010  ...  \
# 0                        NaN     308,745,538         308,758,105  ...
# 1                        NaN       4,779,736           4,780,138  ...
# 2                        0.0          54,571              54,574  ...
# 3                        5.0         182,265             182,264  ...
# 4                        3.0          27,457              27,457  ...
# ...                      ...             ...                 ...  ...
# 3269                     NaN           9,301               9,301  ...
# 3270                     NaN          26,073              26,073  ...
# 3271                     NaN          37,941              37,941  ...
# 3272                     NaN          42,043              41,947  ...
# 3273                     NaN             NaN                 NaN  ...
#
#      R_DOMESTIC_MIG_2017 R_DOMESTIC_MIG_2018 R_NET_MIG_2011 R_NET_MIG_2012  \
# 0                    NaN                 NaN            NaN            NaN
# 1                    0.4                 1.2            0.5            1.2
# 2                    1.1                 0.7            6.0           -6.1
# 3                   22.0                24.3           16.3           17.6
# 4                  -25.5                -9.1            0.3           -6.8
# ...                  ...                 ...            ...            ...
# 3269                 NaN                 NaN            NaN            NaN
# 3270                 NaN                 NaN            NaN            NaN
# 3271                 NaN                 NaN            NaN            NaN
# 3272                 NaN                 NaN            NaN            NaN
# 3273                 NaN                 NaN            NaN            NaN
#
#      R_NET_MIG_2013 R_NET_MIG_2014 R_NET_MIG_2015 R_NET_MIG_2016  \
# 0               NaN            NaN            NaN            NaN
# 1               1.6            0.6            0.6            0.8
# 2              -3.9            2.0           -1.9            5.3
# 3              22.9           20.2           17.9           21.5
# 4              -8.1           -5.1          -15.5          -18.2
# ...             ...            ...            ...            ...
# 3269            NaN            NaN            NaN            NaN
# 3270            NaN            NaN            NaN            NaN
# 3271            NaN            NaN            NaN            NaN
# 3272            NaN            NaN            NaN            NaN
# 3273            NaN            NaN            NaN            NaN
#
#      R_NET_MIG_2017 R_NET_MIG_2018
# 0               NaN            NaN
# 1               1.1            1.9
# 2               1.0            0.6
# 3              22.5           24.8
# 4             -25.0           -8.6
# ...             ...            ...
# 3269            NaN            NaN
# 3270            NaN            NaN
# 3271            NaN            NaN
# 3272            NaN            NaN
# 3273            NaN            NaN
#
# [3274 rows x 149 columns]

# %%
population_df2.describe()
# Out:
#                FIPS  Rural-urban_Continuum Code_2003  \
# count   3273.000000                      3215.000000
# mean   31358.511763                         5.053810
# std    16305.188962                         2.701246
# min        0.000000                         1.000000
# 25%    19025.000000                         3.000000
# 50%    30021.000000                         6.000000
# 75%    46101.000000                         7.000000
# max    72153.000000                         9.000000
#
#        Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# count                      3220.000000                3215.000000
# mean                          4.937888                   5.366096
# std                           2.724344                   3.481577
# min                           1.000000                   1.000000
# 25%                           2.000000                   2.000000
# 50%                           6.000000                   5.000000
# 75%                           7.000000                   8.000000
# max                           9.000000                  12.000000
#
#        Urban_Influence_Code_2013  Economic_typology_2015  RESIDUAL_2016  \
# count                3220.000000             3142.000000    3194.000000
# mean                    5.188820                1.808402       0.000000
# std                     3.506848                1.819511      26.615978
# min                     1.000000                0.000000    -673.000000
# 25%                     2.000000                0.000000      -2.000000
# 50%                     5.000000                1.000000       0.000000
# 75%                     8.000000                3.000000       1.000000
# max                    12.000000                5.000000     759.000000
#
#        RESIDUAL_2017  RESIDUAL_2018  R_birth_2011  ...  R_DOMESTIC_MIG_2017  \
# count    3194.000000    3194.000000   3193.000000  ...          3193.000000
# mean        0.000000       0.000000     11.747667  ...            -0.138647
# std        27.820146      33.206809      2.737269  ...            12.930164
# min      -509.000000    -644.000000      0.000000  ...           -68.800000
# 25%        -2.000000      -2.000000     10.100000  ...            -6.500000
# 50%         0.000000       0.000000     11.500000  ...            -0.500000
# 75%         1.000000       1.000000     13.000000  ...             6.700000
# max       718.000000     918.000000     32.200000  ...           150.200000
#
#        R_DOMESTIC_MIG_2018  R_NET_MIG_2011  R_NET_MIG_2012  R_NET_MIG_2013  \
# count          3193.000000     3193.000000     3193.000000     3193.000000
# mean             -0.006076       -0.967178       -1.577294       -0.601597
# std              11.400081       10.446217       11.854181       11.814311
# min             -62.300000     -128.200000      -99.400000      -98.800000
# 25%              -6.100000       -5.800000       -6.900000       -5.900000
# 50%              -0.500000       -0.900000       -1.700000       -1.000000
# 75%               5.900000        3.700000        3.500000        4.400000
# max              69.400000      122.900000      120.200000      208.300000
#
#        R_NET_MIG_2014  R_NET_MIG_2015  R_NET_MIG_2016  R_NET_MIG_2017  \
# count     3193.000000     3193.000000     3193.000000     3193.000000
# mean        -0.790323       -0.408957       -0.043188        0.987723
# std         11.150211       12.460067       13.075647       12.874758
# min       -174.400000      -75.500000     -108.200000      -68.300000
# 25%         -6.200000       -6.000000       -6.000000       -5.300000
# 50%         -1.100000       -1.000000       -0.600000        0.500000
# 75%          4.300000        5.000000        5.900000        7.500000
# max        150.300000      278.800000      209.700000      150.200000
#
#        R_NET_MIG_2018
# count     3193.000000
# mean         1.138240
# std         11.319971
# min        -62.100000
# 25%         -5.000000
# 50%          0.600000
# 75%          6.800000
# max         69.400000
#
# [8 rows x 57 columns]

# %%
population_df2.FIPS.nunique()
# Out:
# 3273

# %%
#population_df2.FIPS.isnull().sum()
#population_df2.isnull().sum()
population_df2.isnull()
# Out:
#        FIPS  State  Area_Name  Rural-urban_Continuum Code_2003  \
# 0     False  False      False                             True
# 1     False  False      False                             True
# 2     False  False      False                            False
# 3     False  False      False                            False
# 4     False  False      False                            False
# ...     ...    ...        ...                              ...
# 3269  False  False      False                            False
# 3270  False  False      False                            False
# 3271  False  False      False                            False
# 3272  False  False      False                            False
# 3273   True   True       True                             True
#
#       Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 0                                True                       True
# 1                                True                       True
# 2                               False                      False
# 3                               False                      False
# 4                               False                      False
# ...                               ...                        ...
# 3269                            False                      False
# 3270                            False                      False
# 3271                            False                      False
# 3272                            False                      False
# 3273                             True                       True
#
#       Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 0                          True                    True            False
# 1                          True                    True            False
# 2                         False                   False            False
# 3                         False                   False            False
# 4                         False                   False            False
# ...                         ...                     ...              ...
# 3269                      False                    True            False
# 3270                      False                    True            False
# 3271                      False                    True            False
# 3272                      False                    True            False
# 3273                       True                    True             True
#
#       ESTIMATES_BASE_2010  ...  R_DOMESTIC_MIG_2017  R_DOMESTIC_MIG_2018  \
# 0                   False  ...                 True                 True
# 1                   False  ...                False                False
# 2                   False  ...                False                False
# 3                   False  ...                False                False
# 4                   False  ...                False                False
# ...                   ...  ...                  ...                  ...
# 3269                False  ...                 True                 True
# 3270                False  ...                 True                 True
# 3271                False  ...                 True                 True
# 3272                False  ...                 True                 True
# 3273                 True  ...                 True                 True
#
#       R_NET_MIG_2011  R_NET_MIG_2012  R_NET_MIG_2013  R_NET_MIG_2014  \
# 0               True            True            True            True
# 1              False           False           False           False
# 2              False           False           False           False
# 3              False           False           False           False
# 4              False           False           False           False
# ...              ...             ...             ...             ...
# 3269            True            True            True            True
# 3270            True            True            True            True
# 3271            True            True            True            True
# 3272            True            True            True            True
# 3273            True            True            True            True
#
#       R_NET_MIG_2015  R_NET_MIG_2016  R_NET_MIG_2017  R_NET_MIG_2018
# 0               True            True            True            True
# 1              False           False           False           False
# 2              False           False           False           False
# 3              False           False           False           False
# 4              False           False           False           False
# ...              ...             ...             ...             ...
# 3269            True            True            True            True
# 3270            True            True            True            True
# 3271            True            True            True            True
# 3272            True            True            True            True
# 3273            True            True            True            True
#
# [3274 rows x 149 columns]

# %%
population_df2.iloc[[3273]]
# Out:
#       FIPS State Area_Name  Rural-urban_Continuum Code_2003  \
# 3273   NaN   NaN       NaN                              NaN
#
#       Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 3273                              NaN                        NaN
#
#       Urban_Influence_Code_2013  Economic_typology_2015 CENSUS_2010_POP  \
# 3273                        NaN                     NaN             NaN
#
#      ESTIMATES_BASE_2010  ... R_DOMESTIC_MIG_2017 R_DOMESTIC_MIG_2018  \
# 3273                 NaN  ...                 NaN                 NaN
#
#      R_NET_MIG_2011 R_NET_MIG_2012 R_NET_MIG_2013 R_NET_MIG_2014  \
# 3273            NaN            NaN            NaN            NaN
#
#      R_NET_MIG_2015 R_NET_MIG_2016 R_NET_MIG_2017 R_NET_MIG_2018
# 3273            NaN            NaN            NaN            NaN
#
# [1 rows x 149 columns]

# %%
population_df2.drop(population_df2.index[3273]) #drop that last row with all NAs
# Out:
#          FIPS State                         Area_Name  \
# 0         0.0    US                     United States
# 1      1000.0    AL                           Alabama
# 2      1001.0    AL                    Autauga County
# 3      1003.0    AL                    Baldwin County
# 4      1005.0    AL                    Barbour County
# ...       ...   ...                               ...
# 3268  72145.0    PR  Vega Baja Municipio, Puerto Rico
# 3269  72147.0    PR    Vieques Municipio, Puerto Rico
# 3270  72149.0    PR   Villalba Municipio, Puerto Rico
# 3271  72151.0    PR    Yabucoa Municipio, Puerto Rico
# 3272  72153.0    PR      Yauco Municipio, Puerto Rico
#
#       Rural-urban_Continuum Code_2003  Rural-urban_Continuum Code_2013  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 2.0                              2.0
# 3                                 4.0                              3.0
# 4                                 6.0                              6.0
# ...                               ...                              ...
# 3268                              1.0                              1.0
# 3269                              7.0                              7.0
# 3270                              2.0                              2.0
# 3271                              1.0                              1.0
# 3272                              3.0                              2.0
#
#       Urban_Influence_Code_2003  Urban_Influence_Code_2013  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           2.0                        2.0
# 3                           5.0                        2.0
# 4                           6.0                        6.0
# ...                         ...                        ...
# 3268                        1.0                        1.0
# 3269                       12.0                       12.0
# 3270                        2.0                        2.0
# 3271                        1.0                        1.0
# 3272                        2.0                        2.0
#
#       Economic_typology_2015 CENSUS_2010_POP ESTIMATES_BASE_2010  ...  \
# 0                        NaN     308,745,538         308,758,105  ...
# 1                        NaN       4,779,736           4,780,138  ...
# 2                        0.0          54,571              54,574  ...
# 3                        5.0         182,265             182,264  ...
# 4                        3.0          27,457              27,457  ...
# ...                      ...             ...                 ...  ...
# 3268                     NaN          59,662              59,662  ...
# 3269                     NaN           9,301               9,301  ...
# 3270                     NaN          26,073              26,073  ...
# 3271                     NaN          37,941              37,941  ...
# 3272                     NaN          42,043              41,947  ...
#
#      R_DOMESTIC_MIG_2017 R_DOMESTIC_MIG_2018 R_NET_MIG_2011 R_NET_MIG_2012  \
# 0                    NaN                 NaN            NaN            NaN
# 1                    0.4                 1.2            0.5            1.2
# 2                    1.1                 0.7            6.0           -6.1
# 3                   22.0                24.3           16.3           17.6
# 4                  -25.5                -9.1            0.3           -6.8
# ...                  ...                 ...            ...            ...
# 3268                 NaN                 NaN            NaN            NaN
# 3269                 NaN                 NaN            NaN            NaN
# 3270                 NaN                 NaN            NaN            NaN
# 3271                 NaN                 NaN            NaN            NaN
# 3272                 NaN                 NaN            NaN            NaN
#
#      R_NET_MIG_2013 R_NET_MIG_2014 R_NET_MIG_2015 R_NET_MIG_2016  \
# 0               NaN            NaN            NaN            NaN
# 1               1.6            0.6            0.6            0.8
# 2              -3.9            2.0           -1.9            5.3
# 3              22.9           20.2           17.9           21.5
# 4              -8.1           -5.1          -15.5          -18.2
# ...             ...            ...            ...            ...
# 3268            NaN            NaN            NaN            NaN
# 3269            NaN            NaN            NaN            NaN
# 3270            NaN            NaN            NaN            NaN
# 3271            NaN            NaN            NaN            NaN
# 3272            NaN            NaN            NaN            NaN
#
#      R_NET_MIG_2017 R_NET_MIG_2018
# 0               NaN            NaN
# 1               1.1            1.9
# 2               1.0            0.6
# 3              22.5           24.8
# 4             -25.0           -8.6
# ...             ...            ...
# 3268            NaN            NaN
# 3269            NaN            NaN
# 3270            NaN            NaN
# 3271            NaN            NaN
# 3272            NaN            NaN
#
# [3273 rows x 149 columns]
